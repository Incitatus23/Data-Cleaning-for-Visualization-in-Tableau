# %%
import pandas as pd
import numpy as np

oly_df = pd.read_csv("Olympic_Winners.csv")

# %%
oly_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
oly_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
oly_df = oly_df[oly_df["Season"] == "Summer"]

# %%
oly_df["Sport"].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
summer_oly = oly_df.copy()

# %%
dropped_sports = ["Football", "Tug-Of-War", "Art Competitions", "Hockey", "Rugby", "Rugby Sevens",
                 "Trampolining", "Lacrosse", "Polo", "Cricket", "Ice Hockey", "Racquets", "Motorboating",
                 "Croquet", "Figure Skating", "Jeu De Paume", "Roque", "Basque Pelota", "Alpinism",
                 "Aeronautics"]

summer_oly2 = summer_oly[~summer_oly["Sport"].isin(dropped_sports)]

# %%
keep_sports = ["Basketball", "Judo", "Athletics", "Swimming", "Badminton", "Gymnastics",
              "Weightlifting", "Fencing", "Shooting", "Equestrianism", "Boxing",
              "Taekwondo", "Cycling", "Diving", "Tennis", "Archery"]

summer_oly3 = summer_oly2[summer_oly2["Sport"].isin(keep_sports)]

# %%
summer_oly3[summer_oly3["Medal"] == "Gold"]

# %%
gold_df["Event"].unique()
# Out:
# array(["Gymnastics Men's Team All-Around", "Gymnastics Men's Horse Vault",
#        "Gymnastics Men's Pommelled Horse",
#        "Cycling Men's Road Race, Team", "Boxing Men's Light-Welterweight",
#        "Basketball Men's Basketball", "Athletics Men's Hammer Throw",
#        "Athletics Men's Marathon", "Athletics Men's 4 x 400 metres Relay",
#        "Athletics Men's 100 metres",
#        "Gymnastics Men's Team All-Around, Free System",
#        "Cycling Men's Mountainbike, Cross-Country",
#        "Taekwondo Men's Featherweight",
#        "Gymnastics Men's Team All-Around, Swedish System",
#        "Cycling Men's Team Pursuit, 4,000 metres",
#        "Shooting Men's Military Rifle, 200, 400, 500 and 600 metres, Team",
#        "Boxing Women's Flyweight", "Athletics Men's Standing High Jump",
#        "Athletics Women's Shot Put", "Athletics Men's 400 metres Hurdles",
#        "Equestrianism Men's Three-Day Event, Team",
#        "Diving Men's Platform", "Diving Men's Plain High",
# ...

# %%
keep_again = ["Swimming", "Athletics", "Gymnastics"]

gold_df = gold_df[gold_df["Sport"].isin(keep_again)]

# %%
gold_df.dropna(subset=["Age"], inplace=True)
# Out:
# <ipython-input-36-1bd5dc90b481>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gold_df.dropna(subset=["Age"], inplace=True)

# %%
dropped_year = [1896]

gold_df = gold_df[~gold_df["Year"].isin(dropped_year)]

# %%
gold_df.to_csv("Olympic_Winners.csv")

# %%
oly_df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
dropped_events = ["Athletics Men's 1,500 metres Walk", "Athletics Men's 2,500 metres Steeplechase", "Athletics Men's 2,590 metres Steeplechase",
                 "Athletics Men's 3 mile, Team",  "Athletics Men's 3,000 metres Walk", "Athletics Men's 3,000 metres, Team",   "Athletics Men's 3,200 metres Steeplechase",
                "Athletics Men's 3,500 metres Walk",
       "Athletics Men's 4 mile, Team", "Athletics Men's 4,000 metres Steeplechase", "Athletics Men's 5,000 metres, Team",  "Athletics Men's 5 mile",
                  
                "Athletics Men's 56-pound Weight Throw",
       "Athletics Men's 60 metres",  "Athletics Men's All-Around Championship",
       "Athletics Men's Cross-Country, Individual",
       "Athletics Men's Cross-Country, Team",   "Athletics Men's Discus Throw, Both Hands",
       "Athletics Men's Discus Throw, Greek Style",   "Athletics Men's Pentathlon",
       "Athletics Men's Pentathlon (Ancient)", "Athletics Men's Javelin Throw, Both Hands",
       "Athletics Men's Javelin Throw, Freestyle", "Athletics Men's Shot Put, Both Hands",
       "Athletics Men's Standing High Jump",
       "Athletics Men's Standing Long Jump",
       "Athletics Men's Standing Triple Jump",
       "Athletics Men's Stone Throw", "Gymnastics Men's Club Swinging",
                 "Gymnastics Men's Horse Vault",   "Gymnastics Men's Individual All-Around, 4 Events",
       "Gymnastics Men's Individual All-Around, 5 Events",
       "Gymnastics Men's Individual All-Around, Apparatus Work",
       "Gymnastics Men's Individual All-Around, Field Sports", "Gymnastics Men's Team All-Around, Free System",
       "Gymnastics Men's Team All-Around, Swedish System",
       "Gymnastics Men's Tumbling",  "Gymnastics Men's Rope Climbing", "Gymnastics Men's Side Horse", "Gymnastics Women's Team Portable Apparatus",
                  "Swimming Men's 100 Yard Backstroke", "Swimming Men's 100 yard Freestyle",  "Swimming Men's 200 metres Obstacle Course",
       "Swimming Men's 200 metres Team Swimming",
       "Swimming Men's 220 yard Freestyle",   "Swimming Men's 4 x 50 Yard Freestyle Relay",   "Swimming Men's 440 Yard Breaststroke",
       "Swimming Men's 440 yard Freestyle",  "Swimming Men's 50 yard Freestyle",
       "Swimming Men's 880 yard Freestyle",
       "Swimming Men's One Mile Freestyle",
       "Swimming Men's Plunge For Distance",
       "Swimming Men's Underwater Swimming",]
     
gold_df2 = oly_df[~oly_df["Event"].isin(dropped_events)]

# %%
gold_df2["Event"].unique()

gold_df2.to_csv("Olympic_Winners.csv")
