# %%
#common imports and files

import pandas as pd
import numpy as np

hits = pd.read_csv("billboard_info.csv")

audio = pd.read_csv("billboard_audio.csv")

songs = pd.read_csv("top_ten_hits.csv")

# %%
#merge datasets together

billboard = pd.merge(hits, audio, how="inner", left_on="SongID", right_on="SongID")

# %%
#shape of dataset
billboard.shape
# Out:
# (330278, 31)

# %%
hits.shape
# Out:
# (327895, 10)

# %%
audio.shape
# Out:
# (29503, 22)

# %%
#look at first few rows

billboard.head()
# Out:
#                                                  url     WeekID  \
# 0  http://www.billboard.com/charts/hot-100/1965-0...  7/17/1965
# 1  http://www.billboard.com/charts/hot-100/1965-0...  7/24/1965
# 2  http://www.billboard.com/charts/hot-100/1965-0...  7/31/1965
# 3  http://www.billboard.com/charts/hot-100/1965-0...   8/7/1965
# 4  http://www.billboard.com/charts/hot-100/1965-0...  8/14/1965
#
#    Week Position                  Song_x Performer_x  \
# 0             34  Don't Just Stand There  Patty Duke
# 1             22  Don't Just Stand There  Patty Duke
# 2             14  Don't Just Stand There  Patty Duke
# 3             10  Don't Just Stand There  Patty Duke
# 4              8  Don't Just Stand There  Patty Duke
#
#                              SongID  Instance  Previous Week Position  \
# 0  Don't Just Stand TherePatty Duke         1                    45.0
# 1  Don't Just Stand TherePatty Duke         1                    34.0
# ...

# %%
#display more columns and rows

pd.set_option('display.max_columns', 35)
pd.set_option('display.max_rows', 200)

# %%
#filter peak position entry for each song

highest_rank = billboard.groupby("SongID")["Peak Position"].idxmin()

# %%
#convert to list
highest_rank_list = highest_rank.tolist()

# %%
#sort index
billboard2 = billboard.loc[billboard.index[highest_rank_list]].sort_index()

# %%
billboard2 = billboard2.reset_index()

# %%
billboard2
# Out:
#         index                                                url      WeekID  \
# 0           4  http://www.billboard.com/charts/hot-100/1965-0...   8/14/1965
# 1          12  http://www.billboard.com/charts/hot-100/1997-0...   4/26/1997
# 2          26  http://www.billboard.com/charts/hot-100/1971-0...   6/26/1971
# 3          34  http://www.billboard.com/charts/hot-100/1974-0...   8/17/1974
# 4          40  http://www.billboard.com/charts/hot-100/1981-0...   4/11/1981
# ...       ...                                                ...         ...
# 29365  330224  http://www.billboard.com/charts/hot-100/1994-0...    8/6/1994
# 29366  330237  http://www.billboard.com/charts/hot-100/1992-1...  10/17/1992
# 29367  330248  http://www.billboard.com/charts/hot-100/1964-0...   4/18/1964
# 29368  330263  http://www.billboard.com/charts/hot-100/2011-0...   6/25/2011
# 29369  330276  http://www.billboard.com/charts/hot-100/1973-0...    9/1/1973
#
# ...

# %%
#save to csv

billboard2.to_csv("billboard_data2.csv")

# %%
billboard2.sort_values(by="Peak Position")
# Out:
#         index                                                url     WeekID  \
# 4979    69480  http://www.billboard.com/charts/hot-100/1992-0...  6/20/1992
# 12345  153042  http://www.billboard.com/charts/hot-100/1975-0...  2/15/1975
# 2470    35463  https://www.billboard.com/charts/hot-100/2020-...  12/5/2020
# 12340  152966  http://www.billboard.com/charts/hot-100/1973-0...   6/2/1973
# 12337  152931  http://www.billboard.com/charts/hot-100/1971-0...  8/14/1971
# ...       ...                                                ...        ...
# 26127  293584  http://www.billboard.com/charts/hot-100/2009-0...  9/19/2009
# 23596  269957  http://www.billboard.com/charts/hot-100/1962-0...  9/29/1962
# 26115  293408  http://www.billboard.com/charts/hot-100/2008-0...  1/12/2008
# 26138  293693  http://www.billboard.com/charts/hot-100/2011-0...   2/5/2011
# 25842  291439  http://www.billboard.com/charts/hot-100/1963-0...  8/31/1963
#
# ...

# %%
billboard2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29370 entries, 0 to 29369
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      29370 non-null  int64
#  1   url                        29370 non-null  object
#  2   WeekID                     29370 non-null  object
#  3   Week Position              29370 non-null  int64
#  4   Song_x                     29370 non-null  object
#  5   Performer_x                29370 non-null  object
#  6   SongID                     29370 non-null  object
#  7   Instance                   29370 non-null  int64
#  8   Previous Week Position     24306 non-null  float64
#  9   Peak Position              29370 non-null  int64
#  10  Weeks on Chart             29370 non-null  int64
#  11  Performer_y                29370 non-null  object
#  12  Song_y                     29370 non-null  object
# ...

# %%
#convert data type for WEEKID

billboard2["WeekID"] = pd.to_datetime(billboard2.WeekID)

# %%
billboard2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29370 entries, 0 to 29369
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      29370 non-null  int64
#  1   url                        29370 non-null  object
#  2   WeekID                     29370 non-null  datetime64[ns]
#  3   Week Position              29370 non-null  int64
#  4   Song_x                     29370 non-null  object
#  5   Performer_x                29370 non-null  object
#  6   SongID                     29370 non-null  object
#  7   Instance                   29370 non-null  int64
#  8   Previous Week Position     24306 non-null  float64
#  9   Peak Position              29370 non-null  int64
#  10  Weeks on Chart             29370 non-null  int64
#  11  Performer_y                29370 non-null  object
#  12  Song_y                     29370 non-null  object
# ...

# %%
billboard2['year'] = billboard2['WeekID'].dt.year

# %%
billboard2
# Out:
#         index                                                url     WeekID  \
# 0           4  http://www.billboard.com/charts/hot-100/1965-0... 1965-08-14
# 1          12  http://www.billboard.com/charts/hot-100/1997-0... 1997-04-26
# 2          26  http://www.billboard.com/charts/hot-100/1971-0... 1971-06-26
# 3          34  http://www.billboard.com/charts/hot-100/1974-0... 1974-08-17
# 4          40  http://www.billboard.com/charts/hot-100/1981-0... 1981-04-11
# ...       ...                                                ...        ...
# 29365  330224  http://www.billboard.com/charts/hot-100/1994-0... 1994-08-06
# 29366  330237  http://www.billboard.com/charts/hot-100/1992-1... 1992-10-17
# 29367  330248  http://www.billboard.com/charts/hot-100/1964-0... 1964-04-18
# 29368  330263  http://www.billboard.com/charts/hot-100/2011-0... 2011-06-25
# 29369  330276  http://www.billboard.com/charts/hot-100/1973-0... 1973-09-01
#
# ...

# %%
#create decade column

billboard3 = billboard2.copy()

# %%
#add a decade column for each obersvation

fifties = [1955, 1956, 1957, 1958, 1959]
sixties = [1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969]
seventies = [1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979]
eighties = [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989]
nineties = [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999]
aughts = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]
tens = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
twenties = [2020, 2021, 2022]




def add_decade(row):
    if row["year"] >= 1960 and row["year"] < 1970:
        return "1960s"
    elif row["year"] >= 1970 and row["year"] < 1980:
        return "1970s"
    elif row["year"] >= 1980 and row["year"] < 1990:
        return "1980s"
    elif row["year"] >= 1990 and row["year"] < 2000:
        return "1990s"
    elif row["year"] >= 2000 and row["year"] < 2010:
        return "2000s"
    elif row["year"] >= 2010 and row["year"] < 2020:
        return "2010s"
    elif row["year"] >= 2020:
        return "2020s"
    elif row["year"] < 1960:
        return "1950s"

    


billboard3.apply (lambda row: add_decade(row), axis=1)


billboard3['decade'] = billboard3.apply (lambda row: add_decade(row), axis=1)

# %%
#add five year range for each observation

def mid_decade(row):
    if row["year"] >= 1960 and row["year"] < 1965:
        return "1960-1964"
    elif row["year"] >= 1965 and row["year"] < 1970:
        return "1965-1969"
    elif row["year"] >= 1970 and row["year"] < 1975:
        return "1970-1974"
    elif row["year"] >= 1975 and row["year"] < 1980:
        return "1975-1979"
    elif row["year"] >= 1980 and row["year"] < 1985:
        return "1980-1984"
    elif row["year"] >= 1985 and row["year"] < 1990:
        return "1985-1989"
    elif row["year"] >= 1990 and row["year"] < 1995:
        return "1990-1994"
    elif row["year"] >= 1995 and row["year"] < 2000:
        return "1995-1999"
    elif row["year"] >= 2000 and row["year"] < 2005:
        return "2000-2004"
    elif row["year"] >= 2005 and row["year"] < 2010:
        return "2005-2009"
    elif row["year"] >= 2010 and row["year"] < 2015:
        return "2010-2014"
    elif row["year"] >= 2015 and row["year"] < 2020:
        return "2015-2019"
    elif row["year"] >= 2020:
        return "early 2020s"
    elif row["year"] < 1960:
        return "late 1950s"

    


billboard3.apply (lambda row: mid_decade(row), axis=1)


billboard3['mid_decade'] = billboard3.apply (lambda row: mid_decade(row), axis=1)

# %%
billboard3.to_csv('billboard_data2.csv')

# %%
billboard2["year"].unique()
# Out:
# array([1965, 1997, 1971, 1974, 1981, 1989, 1988, 2003, 1998, 1975, 1973,
#        1987, 1977, 1995, 1996, 1999, 2000, 2001, 2002, 2004, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2016, 2017, 2018, 2019, 2020,
#        2021, 1959, 1960, 1962, 1963, 1964, 1966, 1970, 1972, 1978, 1979,
#        1980, 1983, 1984, 1985, 1990, 1993, 1994, 2005, 2014, 2015, 1958,
#        1961, 1969, 1991, 1992, 1968, 1986, 1982, 1976, 1967], dtype=int64)

# %%
#filter out the top ten hits

top_ten = billboard3[billboard3["Peak Position"] <= 10]

# %%
top_ten.to_csv("top_ten_hits.csv")

# %%
pd.set_option('display.max_rows', 200)

top_ten[top_ten["decade"] == "1960s"]
# Out:
#         index                                                url     WeekID  \
# 0           4  http://www.billboard.com/charts/hot-100/1965-0... 1965-08-14
# 76        921  http://www.billboard.com/charts/hot-100/1960-0... 1960-04-16
# 78        939  http://www.billboard.com/charts/hot-100/1962-0... 1962-01-27
# 79        955  http://www.billboard.com/charts/hot-100/1962-0... 1962-05-19
# 80        966  http://www.billboard.com/charts/hot-100/1962-0... 1962-08-04
# ...       ...                                                ...        ...
# 29290  329292  http://www.billboard.com/charts/hot-100/1964-0... 1964-02-01
# 29327  329756  http://www.billboard.com/charts/hot-100/1960-0... 1960-02-06
# 29328  329770  http://www.billboard.com/charts/hot-100/1967-0... 1967-05-13
# 29343  329952  http://www.billboard.com/charts/hot-100/1966-1... 1966-11-19
# 29344  329973  http://www.billboard.com/charts/hot-100/1968-0... 1968-08-31
#
# ...

# %%
top_ten["decade"].value_counts()
# Out:
# 1960s    1055
# 1980s     965
# 1970s     937
# 1990s     677
# 2000s     593
# 2010s     522
# 1950s     127
# 2020s     104
# Name: decade, dtype: int64

# %%
top_ten["mid_decade"].value_counts()
# Out:
# 1985-1989      558
# 1965-1969      532
# 1960-1964      523
# 1970-1974      497
# 1975-1979      440
# 1980-1984      407
# 1990-1994      388
# 2005-2009      312
# 1995-1999      289
# 2000-2004      281
# 2010-2014      266
# 2015-2019      256
# late 1950s     127
# early 2020s    104
# Name: mid_decade, dtype: int64

# %%
songs.drop("Unnamed: 0", axis=1, inplace=True)

# %%
songs2 = songs.drop(["url","WeekID", "Week Position", "Instance", "Previous Week Position",
                    "Weeks on Chart", "Performer_y", "Song_y", "spotify_track_id", "spotify_track_preview_url"], axis=1)

# %%
songs2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4980 entries, 0 to 4979
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      4980 non-null   int64
#  1   Song_x                     4980 non-null   object
#  2   Performer_x                4980 non-null   object
#  3   SongID                     4980 non-null   object
#  4   Peak Position              4980 non-null   int64
#  5   spotify_genre              4751 non-null   object
#  6   spotify_track_duration_ms  4486 non-null   float64
#  7   spotify_track_explicit     4486 non-null   object
#  8   spotify_track_album        4485 non-null   object
#  9   danceability               4480 non-null   float64
#  10  energy                     4480 non-null   float64
#  11  key                        4480 non-null   float64
#  12  loudness                   4480 non-null   float64
# ...

# %%
songs3 = songs2[songs2["danceability"].notna()]

# %%
songs5.to_csv("top_ten.csv")

# %%
songs4 = songs3.rename(columns={"Song_x" : "song", "Performer_x": "artist", "Peak Position":"peak_position",
                      "SongID" : "songid"})

# %%
songs5 = songs4.rename(columns={"spotify_genre": "genre", "spotify_track_duration_ms":"duration",
                      "spotify_track_explicit":"explicit", "spotify_track_album":"album", "peak_position": "peak"})

# %%
songs5["album"].value_counts()
# Out:
# Greatest Hits                         44
# Gold                                  17
# Celebration (double disc version)     13
# The Definitive Collection             13
# Love Songs                            11
#                                       ..
# Open (US Internet Release)             1
# #willpower                             1
# Gitarzan                               1
# Free Yourself                          1
# Greatest Hits Volume I & Volume II     1
# Name: album, Length: 3263, dtype: int64

# %%
songs5["length"] = songs5["duration"]/1000

# %%
songs5["length_mins"] = (songs5["length"]/60).round(2)

# %%
#average length of each song by decade. song length increased and peak in the 1990s before declining again. modern
#hit songs are still not as short as songs in the 50s and 60s

songs5.groupby("decade")["length_mins"].mean()
# Out:
# decade
# 1950s    2.478056
# 1960s    2.793779
# 1970s    3.903400
# 1980s    4.282637
# 1990s    4.466103
# 2000s    4.045709
# 2010s    3.726736
# 2020s    3.141290
# Name: length_mins, dtype: float64

# %%
#looking at the five year ranges, we can see that song lenth peaked in the early 90s
songs5.groupby("mid_decade")["length_mins"].mean()
# Out:
# mid_decade
# 1960-1964      2.611152
# 1965-1969      2.962470
# 1970-1974      3.671510
# 1975-1979      4.150561
# 1980-1984      4.147593
# 1985-1989      4.382144
# 1990-1994      4.535689
# 1995-1999      4.366820
# 2000-2004      4.148924
# 2005-2009      3.959064
# 2010-2014      3.864170
# 2015-2019      3.583502
# early 2020s    3.141290
# late 1950s     2.478056
# Name: length_mins, dtype: float64

# %%
#group decades by average danceability of hit songs; hit songs have increased
#in danceability over time
songs5.groupby("decade")["danceability"].mean()
# Out:
# decade
# 1950s    0.558944
# 1960s    0.547938
# 1970s    0.586627
# 1980s    0.637791
# 1990s    0.647769
# 2000s    0.672798
# 2010s    0.674610
# 2020s    0.673194
# Name: danceability, dtype: float64

# %%
songs5.groupby("mid_decade")["danceability"].mean()
# Out:
# mid_decade
# 1960-1964      0.545315
# 1965-1969      0.550361
# 1970-1974      0.569872
# 1975-1979      0.604485
# 1980-1984      0.640415
# 1985-1989      0.635858
# 1990-1994      0.637930
# 1995-1999      0.661808
# 2000-2004      0.675012
# 2005-2009      0.670940
# 2010-2014      0.649919
# 2015-2019      0.700342
# early 2020s    0.673194
# late 1950s     0.558944
# Name: danceability, dtype: float64

# %%
#group decades by average engergy of hit songs
songs5.groupby("decade")["energy"].mean()
# Out:
# decade
# 1950s    0.491263
# 1960s    0.529219
# 1970s    0.562615
# 1980s    0.649098
# 1990s    0.630194
# 2000s    0.702353
# 2010s    0.679665
# 2020s    0.592516
# Name: energy, dtype: float64

# %%
songs5.groupby("mid_decade")["energy"].mean()
# Out:
# mid_decade
# 1960-1964      0.502459
# 1965-1969      0.553938
# 1970-1974      0.570884
# 1975-1979      0.553801
# 1980-1984      0.619546
# 1985-1989      0.670873
# 1990-1994      0.641188
# 1995-1999      0.614508
# 2000-2004      0.693538
# 2005-2009      0.709753
# 2010-2014      0.718806
# 2015-2019      0.638873
# early 2020s    0.592516
# late 1950s     0.491263
# Name: energy, dtype: float64

# %%
songs5.groupby("decade")["acousticness"].mean()
# Out:
# decade
# 1950s    0.660171
# 1960s    0.498107
# 1970s    0.357024
# 1980s    0.218475
# 1990s    0.205526
# 2000s    0.129262
# 2010s    0.141503
# 2020s    0.318819
# Name: acousticness, dtype: float64

# %%
songs5.groupby("mid_decade")["acousticness"].mean()
# Out:
# mid_decade
# 1960-1964      0.601909
# 1965-1969      0.402225
# 1970-1974      0.389066
# 1975-1979      0.322872
# 1980-1984      0.246420
# 1985-1989      0.197884
# 1990-1994      0.198124
# 1995-1999      0.216086
# 2000-2004      0.162962
# 2005-2009      0.100972
# 2010-2014      0.126498
# 2015-2019      0.157141
# early 2020s    0.318819
# late 1950s     0.660171
# Name: acousticness, dtype: float64

# %%
songs5.groupby("decade")["tempo"].mean()
# Out:
# decade
# 1950s    120.097130
# 1960s    119.778010
# 1970s    117.859885
# 1980s    120.914504
# 1990s    116.729169
# 2000s    118.149307
# 2010s    120.896461
# 2020s    128.962742
# Name: tempo, dtype: float64

# %%
songs5.groupby("mid_decade")["tempo"].mean()
# Out:
# mid_decade
# 1960-1964      118.841315
# 1965-1969      120.643231
# 1970-1974      117.713364
# 1975-1979      118.016056
# 1980-1984      122.106791
# 1985-1989      120.035977
# 1990-1994      116.262674
# 1995-1999      117.394753
# 2000-2004      114.870112
# 2005-2009      120.902077
# 2010-2014      119.529000
# 2015-2019      122.321620
# early 2020s    128.962742
# late 1950s     120.097130
# Name: tempo, dtype: float64

# %%
songs5.groupby("decade")["loudness"].mean()
# Out:
# decade
# 1950s   -10.886917
# 1960s   -10.141360
# 1970s   -10.561806
# 1980s    -9.596897
# 1990s    -8.619974
# 2000s    -5.654013
# 2010s    -5.738343
# 2020s    -7.025694
# Name: loudness, dtype: float64

# %%
songs5.groupby("mid_decade")["loudness"].mean()
# Out:
# mid_decade
# 1960-1964     -10.234730
# 1965-1969     -10.055114
# 1970-1974     -10.463659
# 1975-1979     -10.666417
# 1980-1984      -9.625899
# 1985-1989      -9.575526
# 1990-1994      -9.238501
# 1995-1999      -7.737473
# 2000-2004      -5.772861
# 2005-2009      -5.554244
# 2010-2014      -5.411466
# 2015-2019      -6.079013
# early 2020s    -7.025694
# late 1950s    -10.886917
# Name: loudness, dtype: float64

# %%
songs5.groupby("decade")["instrumentalness"].mean()
# Out:
# decade
# 1950s    0.068012
# 1960s    0.047767
# 1970s    0.040032
# 1980s    0.020803
# 1990s    0.022312
# 2000s    0.012638
# 2010s    0.007789
# 2020s    0.004729
# Name: instrumentalness, dtype: float64

# %%
songs5.groupby("mid_decade")["instrumentalness"].mean()
# Out:
# mid_decade
# 1960-1964      0.059953
# 1965-1969      0.036512
# 1970-1974      0.040993
# 1975-1979      0.039007
# 1980-1984      0.019143
# 1985-1989      0.022026
# 1990-1994      0.025558
# 1995-1999      0.017680
# 2000-2004      0.011233
# 2005-2009      0.013819
# 2010-2014      0.008505
# 2015-2019      0.007042
# early 2020s    0.004729
# late 1950s     0.068012
# Name: instrumentalness, dtype: float64

# %%
songs5.groupby("decade")["speechiness"].mean()
# Out:
# decade
# 1950s    0.061097
# 1960s    0.049461
# 1970s    0.050075
# 1980s    0.044159
# 1990s    0.066065
# 2000s    0.115821
# 2010s    0.112383
# 2020s    0.120235
# Name: speechiness, dtype: float64

# %%
songs5.groupby("decade")["time_signature"].mean()
# Out:
# decade
# 1950s    3.740741
# 1960s    3.882046
# 1970s    3.951594
# 1980s    3.983165
# 1990s    3.965517
# 2000s    3.996364
# 2010s    3.985537
# 2020s    3.967742
# Name: time_signature, dtype: float64

# %%
songs5.groupby("decade")["key"].mean()
# Out:
# decade
# 1950s    5.250000
# 1960s    5.113779
# 1970s    5.181818
# 1980s    5.111111
# 1990s    5.324138
# 2000s    5.200000
# 2010s    5.090909
# 2020s    4.838710
# Name: key, dtype: float64

# %%
songs5.groupby("decade")["mode"].mean()
# Out:
# decade
# 1950s    0.842593
# 1960s    0.811065
# 1970s    0.767414
# 1980s    0.712682
# 1990s    0.667241
# 2000s    0.574545
# 2010s    0.607438
# 2020s    0.612903
# Name: mode, dtype: float64

# %%
songs5.groupby("mid_decade")["mode"].mean()
# Out:
# mid_decade
# 1960-1964      0.847826
# 1965-1969      0.777108
# 1970-1974      0.796339
# 1975-1979      0.736585
# 1980-1984      0.695767
# 1985-1989      0.725146
# 1990-1994      0.715543
# 1995-1999      0.598326
# 2000-2004      0.545817
# 2005-2009      0.598662
# 2010-2014      0.599190
# 2015-2019      0.616034
# early 2020s    0.612903
# late 1950s     0.842593
# Name: mode, dtype: float64

# %%
songs5.groupby("decade")["valence"].mean()
# Out:
# decade
# 1950s    0.692778
# 1960s    0.682611
# 1970s    0.661048
# 1980s    0.652584
# 1990s    0.560896
# 2000s    0.580178
# 2010s    0.517670
# 2020s    0.528605
# Name: valence, dtype: float64

# %%
songs5.groupby("mid_decade")["valence"].mean()
# Out:
# mid_decade
# 1960-1964      0.684689
# 1965-1969      0.680692
# 1970-1974      0.671816
# 1975-1979      0.649570
# 1980-1984      0.669603
# 1985-1989      0.640044
# 1990-1994      0.565605
# 1995-1999      0.554176
# 2000-2004      0.610153
# 2005-2009      0.555015
# 2010-2014      0.546477
# 2015-2019      0.487647
# early 2020s    0.528605
# late 1950s     0.692778
# Name: valence, dtype: float64
